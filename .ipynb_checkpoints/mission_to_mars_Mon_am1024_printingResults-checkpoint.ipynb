# %%
#Libraries
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
#Add for windows use.  (MAC is different.    Ensure chromedriver is in the same directory as this file.)
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Part A - NASA Mars News
#
# Scrape the NASA Mars News Site and collect the latest News Title and Paragraph Text. Assign the text to variables that you can reference later.

# %%
#identify the URL to be scraped
url = 'https://mars.n# Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('a', class_='result-title').text
        # Identify and return price of listing
        price = result.a.span.text
        # Identify and return link to listing
        link = result.a['href']

        # Run only if title, price, and link are available
        if (title and price and link):
            # Print results
            print('-------------')
            print(title)
            print(price)
            print(link)

            # Dictionary to be inserted as a MongoDB document
            post = {
                'title': title,
                'price': price,
                'url': link
            }

            collection.insert_one(post)

    except Exception as e:
        print(e)sa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'
browser.visit(url)

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
results = soup.find_all('li', class_='slide')

# Loop through returned results
for x in range(1, 2):
    try: 
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')

        news_title = soup.find_all('div', class_='content_title')
        news_text = soup.find_all('div', class_='article_teaser_body')
        
        for each in news_title:
            print('page:', x, '-------------')
            print(each.a.text)
        
            #each in news_text;
            #print(each)

    #browser.click_link_by_partial_text('Next')
    
    except:
        print("Please contact Lorie.   Error code:  A-2")
# Out:
# page: 1 -------------
# Why This Martian Full Moon Looks Like Candy
# page: 1 -------------
# For InSight, Dust Cleanings Will Yield New Science
# page: 1 -------------
# InSight Captures Sunrise and Sunset on Mars
# page: 1 -------------
# NASA Social Media and Websites Win Webby Awards
# page: 1 -------------
# NASA's InSight Detects First Likely 'Quake' on Mars
# page: 1 -------------
# Things Are Stacking up for NASA's Mars 2020 Spacecraft
# page: 1 -------------
# Curiosity Tastes First Sample in 'Clay-Bearing Unit'
# page: 1 -------------
# More Testing for Mars InSight's 'Mole'
# page: 1 -------------
# NASA Garners 7 Webby Award Nominations
# page: 1 -------------
# Curiosity Captured Two Solar Eclipses on Mars
# page: 1 -------------
# NASA's Mars Helicopter Completes Flight Tests
# page: 1 -------------
# Asteroids, Hydrogen Make Great Recipe for Life on Mars
# page: 1 -------------
# Catch NASA's JPL at the Clippers SciFest This Weekend
# page: 1 -------------
# ...

# %% [markdown]
# ### Part B - JPL Mars Space Images - Featured Image
#
#
# * Visit the url for JPL Featured Space Image here.
#
#
# * Use splinter to navigate the site and find the image url for the current Featured Mars Image and assign the url string to a variable called featured_image_url.
#
#
# * Make sure to find the image url to the full size .jpg image.
#
#
# * Make sure to save a complete url string for this image.
